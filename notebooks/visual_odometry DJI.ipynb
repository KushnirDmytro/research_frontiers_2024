# %%
import cv2
import os
import numpy as np
import math
import sys
import time
import matplotlib.pyplot as plt

# Get the current working directory and add the src directory to the sys.path
current_dir = os.getcwd()
src_dir = os.path.join(current_dir, '../src/odometry/')
if src_dir not in sys.path:
    sys.path.append(src_dir)

from readcameramodel import readCameraModel
from undistortimage import undistortImage
from imagepreprocessor import ImagePreprocessor

from constants import *

from utils import *

# %%
import cv2
import os
output_dir = '../data/dji_sample/frames'

def load_frames(frame_dir, start_frame, end_frame):
    frames = []

    for frame_id in range(start_frame, end_frame + 1):
        # Construct the filename for each frame
        frame_filename = os.path.join(frame_dir, f'frame_{frame_id:04d}.png')

        # Check if the frame file exists
        if os.path.exists(frame_filename):
            # Load the frame
            frame = cv2.imread(frame_filename)
            frames.append(frame)
        else:
            print(f"Warning: {frame_filename} does not exist.")
    
    return frames

# Directory where frames are saved
frame_dir = output_dir

# Define the range of frames to load
start_frame = 1500
end_frame = 1800

# Load the frames
loaded_frames = load_frames(frame_dir, start_frame, end_frame)

# Verify the frames loaded
print(f"Loaded {len(loaded_frames)} frames from {start_frame} to {end_frame}.")

# Example: Display the first frame in the loaded frames
if loaded_frames:
    cv2.imshow('First Loaded Frame', loaded_frames[0])
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Loaded 301 frames from 1500 to 1800.

# %% [markdown]
# ### Check your openCV multithreading

# %%
# Check the number of threads OpenCV is using
num_threads = cv2.getNumThreads()
print(f"Number of threads OpenCV is using: {num_threads}")

# Generate random descriptors for benchmarking
descriptor1 = np.random.rand(10000, 128).astype(np.float32)
descriptor2 = np.random.rand(10000, 128).astype(np.float32)

# Function to perform FLANN matching
def flann_matcher(descriptor1, descriptor2):
    FLANN_INDEX_KDTREE = 1
    index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
    search_params = dict(checks=50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(descriptor1, descriptor2, k=5)
    return matches

# Benchmark with different numbers of threads
for num_threads in [1, 2, 4, 8, 16]:
    cv2.setNumThreads(num_threads)
    start_time = time.time()
    flann_matcher(descriptor1, descriptor2)
    end_time = time.time()
    print(f"Time taken with {num_threads} threads: {end_time - start_time:.4f} seconds")
# Out:
# Number of threads OpenCV is using: 16
# Time taken with 1 threads: 0.2228 seconds
# Time taken with 2 threads: 0.2196 seconds
# Time taken with 4 threads: 0.2020 seconds
# Time taken with 8 threads: 0.2097 seconds
# Time taken with 16 threads: 0.2066 seconds

# %% [markdown]
# ## Visual odometry

# %%
import cv2
import numpy as np

# Given camera matrix and distortion coefficients
camera_matrix = np.array([
    [921.170702, 0.000000, 459.904354],
    [0.000000, 919.018377, 351.238301],
    [0.000000, 0.000000, 1.000000]
])

distortion = np.array([-0.033458, 0.105152, 0.001256, -0.006647, 0.000000])
undistorted_frames = []
for image in loaded_frames:

    # Undistort the image
    undistorted_image = cv2.undistort(image, camera_matrix, distortion)
    undistorted_frames.append(undistorted_image)

# %%
frame_count = 0

# %%
frame1 = undistorted_frames[0]
frame2 = undistorted_frames[20]
frame1_name =  'frame1'
frame2_name = 'frame2'

# %%
display_plot = True
if display_plot:
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Increase the size of the figure

    axes[0].imshow(frame1, cmap='gray')
    axes[0].set_title(f'Frame 1 (ID: {frame1_name})')  # Add the ID of the image to the title

    axes[1].imshow(frame2, cmap='gray')
    axes[1].set_title(f'Frame 2 (ID: {frame2_name})')  # Add the ID of the image to the title

    plt.show()

# %%
def compute_features(frame1, frame2, filter_matches=True, features_vis=False, matches_vis=False):
    features1 = []
    features2 = []

    # Initiate SIFT detector
    sift = cv2.SIFT_create()
    
    keypoint1, descriptor1 = sift.detectAndCompute(frame1, mask=None)
    keypoint2, descriptor2 = sift.detectAndCompute(frame2, mask=None)
    

    # Draw keypoints on the image
    # Display the image with keypoints
    
    if features_vis:
        image_with_keypoints = cv2.drawKeypoints(frame1, keypoint1, outImage=None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        cv2.imshow('SIFT Keypoints', image_with_keypoints)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

    # FLANN parameters
    FLANN_INDEX_KDTREE = 1 # Original
    # FLANN_INDEX_KDTREE = 0
    index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5) # Original
    # index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=1)
    search_params = dict(checks=50)  # Original
    # search_params = dict(checks=5)   # or pass empty dictionary
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(descriptor1, descriptor2, k=2) # Original
    # matches = flann.knnMatch(descriptor1, descriptor2, k=1)
    
    # Classical 2-matches approach
    # ratio test as per Lowe's paper
    good_matches = []
    if filter_matches:
        for top1, top2 in matches:
            if top1.distance < 0.8*top2.distance:
            # if top1.distance < 1.0*top2.distance: # === for the intentionally bad filtering
                x1, y1 = keypoint1[top1.queryIdx].pt
                x2, y2 = keypoint2[top1.trainIdx].pt
                features1.append([x1, y1, 1])
                features2.append([x2, y2, 1])
                good_matches.append(top1)
    else:
        for top1 in matches:
            x1, y1 = keypoint1[top1[0].queryIdx].pt
            x2, y2 = keypoint2[top1[0].trainIdx].pt
            features1.append([x1, y1, 1])
            features2.append([x2, y2, 1])
            
    if matches_vis:
        image_matches = cv2.drawMatches(frame1, keypoint1,
                                        frame2, keypoint2,
                                        good_matches,
                                        outImg=None, 
                                        flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

        # Display the image with matches
        cv2.imshow('Matches', image_matches)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

    # write_to_file(features1, features2, frame_name)

    features1 = np.ascontiguousarray(features1)
    features2 = np.ascontiguousarray(features2)

    return features1, features2

# %%
compute_features(frame1, frame2, filter_matches=True, features_vis=True, matches_vis=True)
# Out:
# (array([[  5.93506813, 223.81307983,   1.        ],
#         [  8.07874298,   4.51919222,   1.        ],
#         [  8.07874298,   4.51919222,   1.        ],
#         [312.17874146,  91.72967529,   1.        ],
#         [385.16085815, 157.62454224,   1.        ],
#         [494.27203369,  91.78318024,   1.        ],
#         [494.27203369,  91.78318024,   1.        ],
#         [533.56079102, 338.20684814,   1.        ],
#         [663.15606689,  85.92974091,   1.        ],
#         [663.15606689,  85.92974091,   1.        ]]),
#  array([[  6.01320696, 185.67294312,   1.        ],
#         [  8.07882977,   4.55800819,   1.        ],
#         [  8.07882977,   4.55800819,   1.        ],
#         [331.32730103, 162.11103821,   1.        ],
#         [417.76174927, 203.47680664,   1.        ],
#         [331.32730103, 162.11103821,   1.        ],
#         [510.37075806, 124.50632477,   1.        ],
#         [598.0189209 , 349.04510498,   1.        ],
#         [677.94268799,  82.04108429,   1.        ],
#         [677.94268799,  82.04108429,   1.        ]]))

# %% [markdown]
# # Full trajectory pipeline:

# %%
from motionestimator import *
from tqdm import tqdm
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

# Function to combine two images side by side
def combine_images(image1, image2):
    height1, width1 = image1.shape[:2]
    height2, width2 = image2.shape[:2]
    combined_height = max(height1, height2)
    combined_width = width1 + width2

    combined_image = np.zeros((combined_height, combined_width, 3), dtype=np.uint8)
    combined_image[:height1, :width1, :3] = image1
    combined_image[:height2, width1:width1+width2, :3] = image2

    return combined_image

def plot_route(x_coords, z_coords):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.plot(x_coords, -np.array(z_coords), color='r')
    ax.set_xlim(-10, 10)  # Adjust limits as needed
    ax.set_ylim(-10, 10)  # Adjust limits as needed
    canvas = FigureCanvas(fig)
    canvas.draw()

    # Convert canvas to image
    img = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
    img = img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    plt.close(fig)
    return img

# %%
def run():
    # global pre_calc_poses
    K = camera_matrix

    camera_pose = np.eye(4)

    use_openCV_pose = False
    ESTIMATION_METHOD = 'INBUILT_POSE_SELF'
    if use_openCV_pose:
        ESTIMATION_METHOD = 'INBUILT'

    start = time.perf_counter()

    x_coords = []
    z_coords = []

    frame2 = undistorted_frames[1]

    step = 1
    start = 0
    stop = 50 #len(undistorted_frames)
    for frame_count in tqdm(range(0, stop - start + 1, step)):
        frame1 = frame2.copy()
        frame2 = undistorted_frames[frame_count]

        features1, features2 = compute_features(frame1, frame2)

        if use_openCV_pose:
            essential_mat, _ = cv2.findEssentialMat(features1[:, :COL3],
                                                    features2[:, :COL3],
                                                    focal=K[ROW1, COL1], 
                                                    pp=(K[ROW1, COL3], K[ROW2, COL3]), 
                                                    method=cv2.RANSAC,
                                                    prob=0.999, threshold=0.5)
            _, new_R, new_t, mask = cv2.recoverPose(essential_mat, features1[:, :COL3], features2[:, :COL3], K)
            if np.linalg.det(new_R) < 0:
                new_R = -new_R
                new_t = -new_t
                    
        else:
            fundamental_matrix, point_list1, point_list2 = fundmntl_mat_from_8_point_ransac(features1, features2)
            essential_mat = calc_essential_matrix(K, fundamental_matrix)
            poses = get_possible_camera_poses(essential_mat)
            pose = get_correct_pose(poses, point_list1, point_list2, non_linear_flag=False)
            new_R = pose[:, :COL4]
            new_t = pose[:, COL4].reshape(3,1)
                
        new_pose = np.column_stack((new_R, new_t))
        new_pose = np.vstack((new_pose, np.array([0,0,0,1])))

        camera_pose = camera_pose @ new_pose

        x_coord = camera_pose[0, -1]
        z_coord = camera_pose[2, -1]
        x_coords.append(x_coord)
        z_coords.append(z_coord)

        # print('\n\nframe_count', frame_count, frame_name)
        # print('\n\nTime taken: ', (time.perf_counter() - start))

        # plt.scatter(x_coords, -np.array(z_coords), color='r') 
        # plt.pause(0.00001)
        # plt.savefig(PLOT_FILE_PATH.format(ESTIMATION_METHOD, frame_name.zfill(ZERO_PAD)), bbox_inches='tight')
        
        # frm = cv2.resize(frame1, (0,0), fx=0.5, fy=0.5)
        # cv2.imshow('Frame ', frm)


        # if frame_count % 12 == 0:
        # print(f'Frame count: {frame_count}')
        # print(f'x_coord: {x_coord}, z_coord: {z_coord}')
        # print(f'Camera pose: {camera_pose}')

        # Plot current route and convert to image
        route_image = plot_route(x_coords, z_coords)
        route_image = cv2.resize(route_image, (frame1.shape[1] // 2, frame1.shape[0] // 2))
        frame1_resized = cv2.resize(frame1, (frame1.shape[1] // 2, frame1.shape[0] // 2))
        combined_image = combine_images(frame1_resized, route_image)
        cv2.imshow('Combined View', combined_image)

        # cv2.imwrite(f'combined_image_{frame_count}.png', combined_image)

        
        # Break the loop on key press (for example, 'q')
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        if frame_count == 20:
            break

    cv2.imwrite('combined_image.png', combined_image)
    cv2.destroyAllWindows()
    plt.show()

# %%
# %load_ext line_profiler
# %reload_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
run()
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]/tmp/ipykernel_17508/3835546978.py:27: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   img = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
#   8%|▊         | 4/51 [00:00<00:08,  5.44it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# %lprun -f run  run()
# Out:
#  28%|██▊       | 17/61 [00:13<00:34,  1.27it/s]
# Timer unit: 1e-09 s
#
# Total time: 13.3974 s
# File: /tmp/ipykernel_62823/1817582357.py
# Function: run at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run():
#      2                                               global pre_calc_poses
#      3         1        806.0    806.0      0.0      cached = False
#      4         1       1727.0   1727.0      0.0      K = image_processor.intrinsic_camrera_matrix
#      5
#      6         1        551.0    551.0      0.0      features = dict()
#      7         1        319.0    319.0      0.0      if use_cached_features:
#      8                                                   features = load_features()
#      9         1        155.0    155.0      0.0      poses = None
#     10         1        224.0    224.0      0.0      if use_cached_poses:
#     11                                                   pre_calc_poses = load_poses()
#     12
#     13         1      11760.0  11760.0      0.0      init_point = np.array([0, 0, 0, 1])
#     14         1      18135.0  18135.0      0.0      H = np.eye(4)
#     15         1       4252.0   4252.0      0.0      t = np.array([0, 0, 0]).reshape(3,1)
#     16         1      19748.0  19748.0      0.0      R = np.eye(3)
#     17         1       4351.0   4351.0      0.0      camera_pose = np.eye(4)
#     18
#     19         1        206.0    206.0      0.0      use_openCV_pose = True
#     20         1        157.0    157.0      0.0      ESTIMATION_METHOD = 'INBUILT_POSE_SELF'
#     21         1        197.0    197.0      0.0      if use_openCV_pose:
#     22         1        179.0    179.0      0.0          ESTIMATION_METHOD = 'INBUILT'
#     23
#     24         1       1417.0   1417.0      0.0      start = time.perf_counter()
#     25
#     26         1        279.0    279.0      0.0      x_coords = []
#     27         1        179.0    179.0      0.0      z_coords = []
#     28
#     29         1    8644565.0    9e+06      0.1      frame2 = read_image(INIT_IMAGE)
#     30
#     31         1        874.0    874.0      0.0      step = 3
#     32        18   15089027.0 838279.3      0.1      for frame_count in tqdm(range(0, STOP_IMAGE - INIT_IMAGE + 1, step)):
#     33        18    5090454.0 282803.0      0.0          frame1 = frame2.copy()
#     34        18  145288066.0    8e+06      1.1          frame2 = read_image(INIT_IMAGE + frame_count + step)
#     35
#     36        18   40867561.0    2e+06      0.3          if (frame1 is None) or (frame2 is None) or (cv2.waitKey(1) == 27):
#     37                                                       break
#     38
#     39        18      76465.0   4248.1      0.0          frame_name = str(INIT_IMAGE + frame_count)
#     40        18      21946.0   1219.2      0.0          frame2_name = str(INIT_IMAGE + frame_count + step)
#     41
#     42        18       6367.0    353.7      0.0          pose = None
#     43        18      14915.0    828.6      0.0          if pre_calc_poses is not None:
#     44        18      42973.0   2387.4      0.0              pose = pre_calc_poses.get(frame_name)
#     45        18      12258.0    681.0      0.0              if pose is not None:
#     46                                                           pose = np.asarray(pose)
#     47                                                           new_R = pose[:, :COL4]
#     48                                                           new_t = pose[:, COL4].reshape(3,1)
#     49
#     50                                                   # if cache is not available:
#     51        18       9336.0    518.7      0.0          if pose is None:
#     52        18      86207.0   4789.3      0.0              pre_calc_poses = dict()
#     53                                                       # if features_cache is not None and features_cache.get(frame_name) is not None:
#     54                                                       #     features1, features2 = get_cached_features(features_cache, frame_name)
#     55                                                       # else:
#     56                                                           # if cached == False:
#     57                                                           #     cached = True
#     58        18        1e+10    6e+08     84.3              features1, features2 = compute_features(frame1, frame2, frame_name, frame2_name, features_cache)
#     59
#     60        18       9122.0    506.8      0.0              if use_openCV_pose:
#     61        36 1044713607.0    3e+07      7.8                  essential_mat, _ = cv2.findEssentialMat(features1[:, :COL3],
#     62        18      13304.0    739.1      0.0                                                          features2[:, :COL3],
#     63        18      36524.0   2029.1      0.0                                                          focal=K[ROW1, COL1],
#     64        18      10826.0    601.4      0.0                                                          pp=(K[ROW1, COL3], K[ROW2, COL3]),
#     65        18       7810.0    433.9      0.0                                                          method=cv2.RANSAC,
#     66        18       2582.0    143.4      0.0                                                          prob=0.999, threshold=0.5)
#     67        18  307490609.0    2e+07      2.3                  _, new_R, new_t, mask = cv2.recoverPose(essential_mat, features1[:, :COL3], features2[:, :COL3], K)
#     68        18     855998.0  47555.4      0.0                  if np.linalg.det(new_R) < 0:
#     69                                                               new_R = -new_R
#     70                                                               new_t = -new_t
#     71        18     482281.0  26793.4      0.0                  pre_calc_poses[frame_name] = list(np.column_stack((new_R, new_t)))
#     72
#     73                                                       else:
#     74                                                           fundamental_matrix, point_list1, point_list2 = fundmntl_mat_from_8_point_ransac(features1, features2)
#     75                                                           essential_mat = calc_essential_matrix(K, fundamental_matrix)
#     76                                                           poses = get_possible_camera_poses(essential_mat)
#     77                                                           pose = get_correct_pose(poses, point_list1, point_list2, non_linear_flag=False)
#     78                                                           new_R = pose[:, :COL4]
#     79                                                           new_t = pose[:, COL4].reshape(3,1)
#     80                                                           pre_calc_poses[frame_name] = list(pose)
#     81
#     82        36   10543782.0 292882.8      0.1              with open(POSE_FILE, 'w') as pose_file:
#     83        18    2246450.0 124802.8      0.0                  json.dump(pre_calc_poses, pose_file, cls=NumpyArrayEncoder)
#     84
#     85        18     294515.0  16361.9      0.0          new_pose = np.column_stack((new_R, new_t))
#     86        18     488119.0  27117.7      0.0          new_pose = np.vstack((new_pose, np.array([0,0,0,1])))
#     87
#     88        18     222152.0  12341.8      0.0          camera_pose = camera_pose @ new_pose
#     89
#     90        18      38570.0   2142.8      0.0          x_coord = camera_pose[0, -1]
#     91        18       6983.0    387.9      0.0          z_coord = camera_pose[2, -1]
#     92        18       8458.0    469.9      0.0          x_coords.append(x_coord)
#     93        18       5438.0    302.1      0.0          z_coords.append(z_coord)
#     94
#     95                                                   # x_coord = camera_pose[ROW1, -1]
#     96                                                   # z_coord = camera_pose[ROW3, -1]
#     97                                                   # x_coords.append(x_coord)
#     98                                                   # z_coords.append(z_coord)
#     99
#    100                                                   # print('\n\nframe_count', frame_count, frame_name)
#    101                                                   # print('\n\nTime taken: ', (time.perf_counter() - start))
#    102
#    103                                                   # plt.scatter(x_coords, -np.array(z_coords), color='r')
#    104                                                   # plt.pause(0.00001)
#    105                                                   # plt.savefig(PLOT_FILE_PATH.format(ESTIMATION_METHOD, frame_name.zfill(ZERO_PAD)), bbox_inches='tight')
#    106
#    107                                                   # frm = cv2.resize(frame1, (0,0), fx=0.5, fy=0.5)
#    108                                                   # cv2.imshow('Frame ', frm)
#    109
#    110
#    111        18      10443.0    580.2      0.0          if frame_count % 12 == 0:
#    112                                                       # print(f'Frame count: {frame_count}')
#    113                                                       # print(f'x_coord: {x_coord}, z_coord: {z_coord}')
#    114                                                       # print(f'Camera pose: {camera_pose}')
#    115
#    116                                                       # Plot current route and convert to image
#    117         5  392967915.0    8e+07      2.9              route_image = plot_route(x_coords, z_coords)
#    118         5    2921620.0 584324.0      0.0              route_image = cv2.resize(route_image, (frame1.shape[1] // 2, frame1.shape[0] // 2))
#    119         5    1325840.0 265168.0      0.0              frame1_resized = cv2.resize(frame1, (frame1.shape[1] // 2, frame1.shape[0] // 2))
#    120         5     973724.0 194744.8      0.0              combined_image = combine_images(frame1_resized, route_image)
#    121         5    5592437.0    1e+06      0.0              cv2.imshow('Combined View', combined_image)
#    122
#    123         5   53934791.0    1e+07      0.4              cv2.imwrite(f'combined_image_{frame_count}.png', combined_image)
#    124
#    125
#    126                                                   # Break the loop on key press (for example, 'q')
#    127        18   47135339.0    3e+06      0.4          if cv2.waitKey(1) & 0xFF == ord('q'):
#    128         1    1040077.0    1e+06      0.0              break
#    129
#    130                                                   # if frame_count == 20:
#    131                                                   #     break
#    132
#    133         1   11987982.0    1e+07      0.1      cv2.imwrite('combined_image.png', combined_image)
#    134         1    1191931.0    1e+06      0.0      cv2.destroyAllWindows()
#    135         1      75570.0  75570.0      0.0      plt.show()

# %%
# %lprun -f fundmntl_mat_from_8_point_ransac fundmntl_mat_from_8_point_ransac(features1, features2)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 3.44742 s
# File: /home/dkushn/projects/research_frontiers_2024/notebooks/../src/odometry/utils.py
# Function: fundmntl_mat_from_8_point_ransac at line 33
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     33                                           def fundmntl_mat_from_8_point_ransac(point_list1, point_list2):
#     34         1        944.0    944.0      0.0      fundamental_mat_model = FundamentalMatrixModel()
#     35         1       2280.0   2280.0      0.0      ransac_model = Ransac(fundamental_mat_model)
#     36
#     37         1     510566.0 510566.0      0.0      total_data = np.column_stack((point_list1, point_list2))
#     38         1 3446907213.0    3e+09    100.0      fundamental_mat, point_list1, point_list2 = ransac_model.fit(total_data, N_POINT, RANSAC_THRESH)
#     39         1        259.0    259.0      0.0      return fundamental_mat, point_list1, point_list2

# %%
features_cache = dict()
compute_features

# %%
# %lprun -f compute_features  compute_features(frame1, frame2, frame_name, frame2_name, features_cache)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.847939 s
# File: /tmp/ipykernel_62823/574242906.py
# Function: compute_features at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def compute_features(frame1, frame2, frame_name, frame2_name, features_cache):
#      2         1        415.0    415.0      0.0      features1 = []
#      3         1        168.0    168.0      0.0      features2 = []
#      4
#      5                                               # Initiate SIFT detector
#      6         1       7375.0   7375.0      0.0      sift = cv2.SIFT_create()
#      7
#      8                                               # find the keypoints and descriptors with SIFT
#      9         1        241.0    241.0      0.0      if features_cache is not None:
#     10         1        469.0    469.0      0.0          if frame_name in features_cache:
#     11         1        583.0    583.0      0.0              keypoint1, descriptor1 = features_cache.get(frame_name)
#     12         1  119454934.0    1e+08     14.1              keypoint2, descriptor2 = sift.detectAndCompute(frame2, mask=None)
#     13         1      43830.0  43830.0      0.0              features_cache[frame2_name] = (keypoint2, descriptor2)
#     14                                                   else:
#     15                                                       keypoint1, descriptor1 = sift.detectAndCompute(frame1, mask=None)
#     16                                                       keypoint2, descriptor2 = sift.detectAndCompute(frame2, mask=None)
#     17                                                       features_cache[frame2_name] = (keypoint2, descriptor2)
#     18                                               else:
#     19                                                   keypoint1, descriptor1 = sift.detectAndCompute(frame1, mask=None)
#     20                                                   keypoint2, descriptor2 = sift.detectAndCompute(frame2, mask=None)
#     21
#     22
#     23                                               # Draw keypoints on the image
#     24                                               # Display the image with keypoints
#     25         1        475.0    475.0      0.0      detailed_vis = False
#     26         1        359.0    359.0      0.0      if detailed_vis:
#     27                                                   image_with_keypoints = cv2.drawKeypoints(frame1, keypoint1, outImage=None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#     28                                                   cv2.imshow('SIFT Keypoints', image_with_keypoints)
#     29                                                   cv2.waitKey(0)
#     30                                                   cv2.destroyAllWindows()
#     31
#     32                                               # FLANN parameters
#     33                                               # FLANN_INDEX_KDTREE = 1 # Original
#     34         1        489.0    489.0      0.0      FLANN_INDEX_KDTREE = 0
#     35                                               # index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5) # Original
#     36         1       3279.0   3279.0      0.0      index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=1)
#     37                                               # search_params = dict(checks=50)  # Original
#     38         1        525.0    525.0      0.0      search_params = dict(checks=5)   # or pass empty dictionary
#     39         1      16319.0  16319.0      0.0      flann = cv2.FlannBasedMatcher(index_params, search_params)
#     40                                               # matches = flann.knnMatch(descriptor1, descriptor2, k=2) # Original
#     41         1  720319662.0    7e+08     84.9      matches = flann.knnMatch(descriptor1, descriptor2, k=1)
#     42
#     43                                               # ratio test as per Lowe's paper
#     44                                               # good_matches = []
#     45                                               # for i, (top1, top2) in enumerate(matches):
#     46                                               #     if top1.distance < 0.8*top2.distance:
#     47                                               #     # if top1.distance < 1.0*top2.distance: # === for the intentionally bad filtering
#     48                                               #         x1, y1 = keypoint1[top1.queryIdx].pt
#     49                                               #         x2, y2 = keypoint2[top1.trainIdx].pt
#     50                                               #         features1.append([x1, y1, 1])
#     51                                               #         features2.append([x2, y2, 1])
#     52                                               #         good_matches.append(top1)
#     53
#     54         1        489.0    489.0      0.0      good_matches = []
#     55      4204     576693.0    137.2      0.1      for top1 in matches:
#     56                                                   # if top1.distance < 0.8*top2.distance:
#     57                                                   # if top1.distance < 1.0*top2.distance: # === for the intentionally bad filtering
#     58      4203    1326379.0    315.6      0.2          x1, y1 = keypoint1[top1[0].queryIdx].pt
#     59      4203    1317834.0    313.5      0.2          x2, y2 = keypoint2[top1[0].trainIdx].pt
#     60      4203    1180000.0    280.8      0.1          features1.append([x1, y1, 1])
#     61      4203    1310865.0    311.9      0.2          features2.append([x2, y2, 1])
#     62
#     63
#     64         1        248.0    248.0      0.0      display_matches = False
#     65         1        206.0    206.0      0.0      if display_matches:
#     66                                                   image_matches = cv2.drawMatches(frame1, keypoint1,
#     67                                                                                   frame2, keypoint2,
#     68                                                                                   good_matches,
#     69                                                                                   outImg=None,
#     70                                                                                   flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#     71
#     72                                                   # Display the image with matches
#     73                                                   cv2.imshow('Matches', image_matches)
#     74                                                   cv2.waitKey(0)
#     75                                                   cv2.destroyAllWindows()
#     76
#     77                                               # write_to_file(features1, features2, frame_name)
#     78
#     79         1    1197215.0    1e+06      0.1      features1 = np.ascontiguousarray(features1)
#     80         1    1179563.0    1e+06      0.1      features2 = np.ascontiguousarray(features2)
#     81
#     82         1        256.0    256.0      0.0      return features1, features2

# %%
# %lprun -f run run()
# Out:
#  11%|█         | 20/181 [00:02<00:16,  9.68it/s]
# Timer unit: 1e-09 s
#
# Total time: 2.06794 s
# File: /tmp/ipykernel_59660/2194246613.py
# Function: run at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run():
#      2                                               global pre_calc_poses
#      3         1        846.0    846.0      0.0      cached = False
#      4         1       1511.0   1511.0      0.0      K = image_processor.intrinsic_camrera_matrix
#      5
#      6         1        172.0    172.0      0.0      features = None
#      7         1        386.0    386.0      0.0      if use_cached_features:
#      8                                                   features = load_features()
#      9         1        186.0    186.0      0.0      poses = None
#     10         1        261.0    261.0      0.0      if use_cached_poses:
#     11                                                   pre_calc_poses = load_poses()
#     12
#     13         1      12184.0  12184.0      0.0      init_point = np.array([0, 0, 0, 1])
#     14         1      18160.0  18160.0      0.0      H = np.eye(4)
#     15         1       4559.0   4559.0      0.0      t = np.array([0, 0, 0]).reshape(3,1)
#     16         1       5723.0   5723.0      0.0      R = np.eye(3)
#     17         1       4475.0   4475.0      0.0      camera_pose = np.eye(4)
#     18
#     19         1        198.0    198.0      0.0      use_openCV_pose = True
#     20         1        188.0    188.0      0.0      ESTIMATION_METHOD = 'INBUILT_POSE_SELF'
#     21         1        205.0    205.0      0.0      if use_openCV_pose:
#     22         1        199.0    199.0      0.0          ESTIMATION_METHOD = 'INBUILT'
#     23
#     24         1       1153.0   1153.0      0.0      start = time.perf_counter()
#     25
#     26         1        217.0    217.0      0.0      x_coords = []
#     27         1        241.0    241.0      0.0      z_coords = []
#     28
#     29        21    5154609.0 245457.6      0.2      for frame_count in tqdm(range(STOP_IMAGE - INIT_IMAGE + 1)):
#     30        21  159711720.0    8e+06      7.7          frame1 = read_image(INIT_IMAGE + frame_count)
#     31        21  159018743.0    8e+06      7.7          frame2 = read_image(INIT_IMAGE + frame_count + 1)
#     32
#     33
#     34        21     107894.0   5137.8      0.0          if (frame1 is None) or (frame2 is None) or (cv2.waitKey(1) == 27):
#     35                                                       break
#     36
#     37        21      46174.0   2198.8      0.0          frame_name = str(INIT_IMAGE + frame_count)
#     38
#     39        21       4215.0    200.7      0.0          pose = None
#     40        21      14707.0    700.3      0.0          if pre_calc_poses is not None:
#     41        21      30301.0   1442.9      0.0              pose = pre_calc_poses.get(frame_name)
#     42        21      12459.0    593.3      0.0              if pose is not None:
#     43                                                           pose = np.asarray(pose)
#     44                                                           new_R = pose[:, :COL4]
#     45                                                           new_t = pose[:, COL4].reshape(3,1)
#     46
#     47                                                   # if cache is not available:
#     48        21       9251.0    440.5      0.0          if pose is None:
#     49        21      59501.0   2833.4      0.0              pre_calc_poses = dict()
#     50        21      10681.0    508.6      0.0              if features_cache is not None and features_cache.get(frame_name) is not None:
#     51                                                           features1, features2 = get_cached_features(features_cache, frame_name)
#     52                                                       else:
#     53        21       9370.0    446.2      0.0                  if cached == False:
#     54         1        214.0    214.0      0.0                      cached = True
#     55         1 1446479762.0    1e+09     69.9                      features1, features2 = compute_features(frame1, frame2, frame_name)
#     56
#     57        21       4866.0    231.7      0.0              if use_openCV_pose:
#     58        42   67349037.0    2e+06      3.3                  essential_mat, _ = cv2.findEssentialMat(features1[:, :COL3],
#     59        21      14539.0    692.3      0.0                                                          features2[:, :COL3],
#     60        21      35320.0   1681.9      0.0                                                          focal=K[ROW1, COL1],
#     61        21      14967.0    712.7      0.0                                                          pp=(K[ROW1, COL3], K[ROW2, COL3]),
#     62        21      14644.0    697.3      0.0                                                          method=cv2.RANSAC,
#     63        21       5615.0    267.4      0.0                                                          prob=0.999, threshold=0.5)
#     64        21  221061185.0    1e+07     10.7                  _, new_R, new_t, mask = cv2.recoverPose(essential_mat, features1[:, :COL3], features2[:, :COL3], K)
#     65        21     941821.0  44848.6      0.0                  if np.linalg.det(new_R) < 0:
#     66                                                               new_R = -new_R
#     67                                                               new_t = -new_t
#     68        21     546486.0  26023.1      0.0                  pre_calc_poses[frame_name] = list(np.column_stack((new_R, new_t)))
#     69
#     70                                                       else:
#     71                                                           fundamental_matrix, point_list1, point_list2 = fundmntl_mat_from_8_point_ransac(features1, features2)
#     72                                                           essential_mat = calc_essential_matrix(K, fundamental_matrix)
#     73                                                           poses = get_possible_camera_poses(essential_mat)
#     74                                                           pose = get_correct_pose(poses, point_list1, point_list2, non_linear_flag=False)
#     75                                                           new_R = pose[:, :COL4]
#     76                                                           new_t = pose[:, COL4].reshape(3,1)
#     77                                                           pre_calc_poses[frame_name] = list(pose)
#     78
#     79        42    2501270.0  59554.0      0.1              with open(POSE_FILE, 'w') as pose_file:
#     80        21    2578137.0 122768.4      0.1                  json.dump(pre_calc_poses, pose_file, cls=NumpyArrayEncoder)
#     81
#     82        21     285117.0  13577.0      0.0          new_pose = np.column_stack((new_R, new_t))
#     83        21     636617.0  30315.1      0.0          new_pose = np.vstack((new_pose, np.array([0,0,0,1])))
#     84
#     85        21     282876.0  13470.3      0.0          camera_pose = camera_pose @ new_pose
#     86
#     87        21      35712.0   1700.6      0.0          x_coord = camera_pose[0, -1]
#     88        21      10250.0    488.1      0.0          z_coord = camera_pose[2, -1]
#     89        21       9878.0    470.4      0.0          x_coords.append(x_coord)
#     90        21       6152.0    293.0      0.0          z_coords.append(z_coord)
#     91
#     92                                                   # x_coord = camera_pose[ROW1, -1]
#     93                                                   # z_coord = camera_pose[ROW3, -1]
#     94                                                   # x_coords.append(x_coord)
#     95                                                   # z_coords.append(z_coord)
#     96
#     97                                                   # print('\n\nframe_count', frame_count, frame_name)
#     98                                                   # print('\n\nTime taken: ', (time.perf_counter() - start))
#     99
#    100                                                   # plt.scatter(x_coords, -np.array(z_coords), color='r')
#    101                                                   # plt.pause(0.00001)
#    102                                                   # plt.savefig(PLOT_FILE_PATH.format(ESTIMATION_METHOD, frame_name.zfill(ZERO_PAD)), bbox_inches='tight')
#    103
#    104                                                   # frm = cv2.resize(frame1, (0,0), fx=0.5, fy=0.5)
#    105                                                   # cv2.imshow('Frame ', frm)
#    106
#    107
#    108                                                   # if frame_count % 10 == 0:
#    109                                                   #     # print(f'Frame count: {frame_count}')
#    110                                                   #     # print(f'x_coord: {x_coord}, z_coord: {z_coord}')
#    111                                                   #     # print(f'Camera pose: {camera_pose}')
#    112
#    113                                                   #     # Plot current route and convert to image
#    114                                                   #     route_image = plot_route(x_coords, z_coords)
#    115                                                   #     route_image = cv2.resize(route_image, (frame1.shape[1] // 2, frame1.shape[0] // 2))
#    116                                                   #     frame1_resized = cv2.resize(frame1, (frame1.shape[1] // 2, frame1.shape[0] // 2))
#    117                                                   #     combined_image = combine_images(frame1_resized, route_image)
#    118                                                   #     cv2.imshow('Combined View', combined_image)
#    119
#    120                                                   #     cv2.imwrite(f'combined_image_{frame_count}.png', combined_image)
#    121
#    122
#    123                                                   # Break the loop on key press (for example, 'q')
#    124        21     136124.0   6482.1      0.0          if cv2.waitKey(1) & 0xFF == ord('q'):
#    125                                                       break
#    126
#    127        21       9897.0    471.3      0.0          if frame_count == 20:
#    128         1     741028.0 741028.0      0.0              break
#    129
#    130                                               # cv2.imwrite('combined_image.png', combined_image)
#    131                                               # cv2.destroyAllWindows()
#    132                                               # plt.show()

# %%
# Sample data for testing
x_coords = [0, 1, 2, 3]
z_coords = [0, 1, 4, 9]

# %lprun -f plot_route plot_route(x_coords, z_coords)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.0778563 s
# File: /tmp/ipykernel_59660/2948893975.py
# Function: plot_route at line 18
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     18                                           def plot_route(x_coords, z_coords):
#     19         1   26213174.0    3e+07     33.7      fig, ax = plt.subplots(figsize=(5, 5))
#     20         1     742847.0 742847.0      1.0      ax.plot(x_coords, -np.array(z_coords), color='r')
#     21         1     800771.0 800771.0      1.0      ax.set_xlim(-1, 100)  # Adjust limits as needed
#     22         1      97749.0  97749.0      0.1      ax.set_ylim(-1, 100)  # Adjust limits as needed
#     23         1      14668.0  14668.0      0.0      canvas = FigureCanvas(fig)
#     24         1   46441337.0    5e+07     59.7      canvas.draw()
#     25
#     26                                               # Convert canvas to image
#     27         1    3469378.0    3e+06      4.5      img = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
#     28         1      41834.0  41834.0      0.1      img = img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#     29         1      34375.0  34375.0      0.0      plt.close(fig)
#     30         1        147.0    147.0      0.0      return img
